# %% [markdown]
# # Auswertungen

# %% [markdown]
# ## Sales CSV mit Werten:
#
# - Region
# - Country
# - Item Type
# - Sales Channel
# - Order Priority
# - Order Date
# - Order ID
# - Ship Date
# - Units Sold
# - Unit Price
# - Unit Cost
# - Total Revenue
# - Total Cost
# - Total Profit

# %%
import pandas

df = pandas.read_csv('datas/sales.csv')
df
# Out:
#                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %% [markdown]
# ## Index setzen
#
# Ein DataFrame generiert automatisch Indezes für die Reihen.
# Um die Indezes zu setzten benutzen wir `set_index` mit der `Order ID`

# %%
import pandas

df = pandas.read_csv('datas/sales.csv')
df = df.set_index('Order ID')
df
# Out:
#                                  Region                           Country  \
# Order ID
# 292494523            Sub-Saharan Africa                              Chad
# 361825549                        Europe                            Latvia
# 141515767  Middle East and North Africa                          Pakistan
# 500364005            Sub-Saharan Africa  Democratic Republic of the Congo
# 127481591                        Europe                    Czech Republic
# ...                                 ...                               ...
# 199342048                          Asia                              Laos
# 763044106                        Europe                     Liechtenstein
# 848579967            Sub-Saharan Africa  Democratic Republic of the Congo
# 298185956            Sub-Saharan Africa                      South Africa
# 824410903                          Asia                          Mongolia
#
# ...

# %% [markdown]
# ## Zeiten umwandeln
#
# Dafür nutzen wir `pandas.to_datetime`

# %%
import pandas

df = pandas.read_csv('datas/sales.csv')
df = df.set_index('Order ID')
# In Datetime umwandeln
df['Order Date'] = pandas.to_datetime(df['Order Date'])
df['Ship Date'] = pandas.to_datetime(df['Ship Date'])
df
# Out:
#                                  Region                           Country  \
# Order ID
# 292494523            Sub-Saharan Africa                              Chad
# 361825549                        Europe                            Latvia
# 141515767  Middle East and North Africa                          Pakistan
# 500364005            Sub-Saharan Africa  Democratic Republic of the Congo
# 127481591                        Europe                    Czech Republic
# ...                                 ...                               ...
# 199342048                          Asia                              Laos
# 763044106                        Europe                     Liechtenstein
# 848579967            Sub-Saharan Africa  Democratic Republic of the Congo
# 298185956            Sub-Saharan Africa                      South Africa
# 824410903                          Asia                          Mongolia
#
# ...

# %% [markdown]
# ## Sortieren des DataFrames

# %%
import pandas

df = pandas.read_csv('datas/sales.csv')

#Index setzen
df = df.set_index('Order ID')

# In Datetime umwandeln
df['Order Date'] = pandas.to_datetime(df['Order Date'])
df['Ship Date'] = pandas.to_datetime(df['Ship Date'])

# Sortieren
df = df.sort_values('Order Date')
df
# Out:
#                                  Region                   Country   Item Type  \
# Order ID
# 506209075            Sub-Saharan Africa  Central African Republic  Vegetables
# 863776719                          Asia                     China      Cereal
# 907228076                        Europe                    Sweden     Clothes
# 335552775            Sub-Saharan Africa         Equatorial Guinea      Snacks
# 695167052                          Asia                  Mongolia   Cosmetics
# ...                                 ...                       ...         ...
# 861848104            Sub-Saharan Africa                     Ghana      Snacks
# 126010453                        Europe                   Ireland  Vegetables
# 651951730                          Asia                  Thailand   Cosmetics
# 204962670            Sub-Saharan Africa                     Kenya   Baby Food
# 456617820  Middle East and North Africa                Azerbaijan     Clothes
#
# ...

# %% [markdown]
# ## Werte filtern

# %%
import pandas

df = pandas.read_csv('datas/sales.csv')

#Index setzen
df = df.set_index('Order ID')

# In Datetime umwandeln
df['Order Date'] = pandas.to_datetime(df['Order Date'])
df['Ship Date'] = pandas.to_datetime(df['Ship Date'])

# Sortieren
df = df.sort_values('Order Date')

# Filtern
df = df.query('"2012-01-01" <= `Order Date` & `Order Date` <= "2012-12-31"')
df = df.query('Region == "Europe"')
df
# Out:
#            Region                 Country        Item Type Sales Channel  \
# Order ID
# 806347405  Europe                 Iceland        Cosmetics       Offline
# 440357196  Europe             Netherlands        Cosmetics       Offline
# 889156854  Europe                 Belarus       Vegetables        Online
# 462988173  Europe                  Monaco             Meat        Online
# 452755010  Europe                 Denmark       Vegetables        Online
# ...           ...                     ...              ...           ...
# 893640220  Europe  Bosnia and Herzegovina           Fruits        Online
# 629469239  Europe                 Andorra        Baby Food        Online
# 914106547  Europe             Switzerland    Personal Care        Online
# 126158940  Europe          United Kingdom  Office Supplies       Offline
# 552327620  Europe                 Ireland           Fruits        Online
#
#           Order Priority Order Date  Ship Date  Units Sold  Unit Price  \
# ...

# %% [markdown]
# ## Filtern und sortieren

# %%
df = df.query('Country == "Germany" or Country == "France"').sort_values('Country')
df
# Out:
#            Region  Country        Item Type Sales Channel Order Priority  \
# Order ID
# 813403117  Europe   France           Fruits       Offline              L
# 715642821  Europe   France          Clothes       Offline              C
# 613118493  Europe   France             Meat       Offline              M
# 717502772  Europe   France           Snacks        Online              L
# 535173070  Europe  Germany        Household       Offline              H
# 508256137  Europe  Germany       Vegetables        Online              L
# 343512713  Europe  Germany           Snacks        Online              L
# 848086869  Europe  Germany  Office Supplies        Online              L
# 553663146  Europe  Germany        Baby Food        Online              M
#
#           Order Date  Ship Date  Units Sold  Unit Price  Unit Cost  \
# Order ID
# 813403117 2012-04-17 2012-06-01        2913        9.33       6.92
# 715642821 2012-06-07 2012-06-26        3469      109.28      35.84
# ...

# %% [markdown]
# ## Neue Werte reinschreiben

# %%
df['Fulfilment Delta'] = df['Ship Date'] - df['Order Date']
df
# Out:
#            Region  Country        Item Type Sales Channel Order Priority  \
# Order ID
# 813403117  Europe   France           Fruits       Offline              L
# 715642821  Europe   France          Clothes       Offline              C
# 613118493  Europe   France             Meat       Offline              M
# 717502772  Europe   France           Snacks        Online              L
# 535173070  Europe  Germany        Household       Offline              H
# 508256137  Europe  Germany       Vegetables        Online              L
# 343512713  Europe  Germany           Snacks        Online              L
# 848086869  Europe  Germany  Office Supplies        Online              L
# 553663146  Europe  Germany        Baby Food        Online              M
#
#           Order Date  Ship Date  Units Sold  Unit Price  Unit Cost  \
# Order ID
# 813403117 2012-04-17 2012-06-01        2913        9.33       6.92
# 715642821 2012-06-07 2012-06-26        3469      109.28      35.84
# ...

# %% [markdown]
# ## Schnelle Auswertungen

# %%
order_id = df['Total Profit'].idxmax()
df.loc[order_id]
# Out:
# Region                           Europe
# Country                         Germany
# Item Type                     Household
# Sales Channel                   Offline
# Order Priority                        H
# Order Date          2012-01-26 00:00:00
# Ship Date           2012-02-21 00:00:00
# Units Sold                         8459
# Unit Price                       668.27
# Unit Cost                        502.54
# Total Revenue                5.6529e+06
# Total Cost                  4.25099e+06
# Total Profit                1.40191e+06
# Fulfilment Delta       26 days 00:00:00
# Name: 535173070, dtype: object

# %% [markdown]
# ## Summe von Series

# %%
df['Total Revenue'].sum()
# Out:
# 13536040.42
